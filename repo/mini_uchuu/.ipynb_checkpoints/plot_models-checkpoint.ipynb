# %%
# %load_ext autoreload
# %autoreload 2
# import matplotlib.pyplot as plt
# import sys
# sys.path.append('../y1')
# from plot_lensing_y1 import plot_lensing_y1
# fig, axes = plt.subplots(1, 4, figsize=(20, 5))
# plot_lensing_y1(axes, thresholded=False)

# from plot_lensing_mini_uchuu import *
# plmu = PlotLensingMiniUchuu(0, 30, abundance_matching=True, thresholded=False)
# plmu.plot_lensing(axes)
# Out:
# No handles with labels found to put in legend.
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# plmu = PlotLensingMiniUchuu(0, 30, abundance_matching=True, thresholded=False)
# plmu.plot_lensing(plot_bias=True)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import sys
sys.path.append('../y1')
from plot_lensing_y1 import plot_lensing_y1

fig, axes = plt.subplots(1, 4, figsize=(20, 5))
plot_lensing_y1(axes, thresholded=False)
from plot_lensing import PlotLensing
depth = 30
for model_id in range(4):
    plmu = PlotLensing('mini_uchuu', model_id, depth, 
                   abundance_matching=True, thresholded=False)
    plmu.plot_lensing(axes)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
fig, axes = plt.subplots(2, 4, figsize=(20, 10))
from plot_lensing import PlotLensing
for model_id in range(4):
    plmu = PlotLensing('mini_uchuu', model_id, depth, 
                   abundance_matching=True, thresholded=False)
    plmu.plot_lensing(axes, plot_bias=True)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# ...

# %%
# %load_ext autoreload
# %autoreload 2
from plot_counts_richness_y1 import plot_counts_richness_y1
from calc_counts_richness import CalcCountsRichness
depth = 30

fig, axes = plt.subplots(1, 1, figsize=(7, 7))
plot_counts_richness_y1(axes)
for model_id in range(4):
    ccr = CalcCountsRichness('mini_uchuu', model_id, depth)
    ccr.plot_counts_richness(axes)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
